# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import requests
import json
from bs4 import BeautifulSoup
import time
import sys
import pandas as pd
import numpy as np
from datetime import datetime
import re

# %%
BASE_URL = 'https://soundcloud.com'
CACHE_FILENAME = 'cache.json'
CACHE_DICT = {}
SCROLL_PAUSE_TIME = 1
CHROMEDRIVER_PATH = './chromedriver'

# %%
def open_cache():
    '''
    Opens the cache file if it exists and loads the JSON into
    the CACHE_DICT dictionary.
    if the cache file doesn't exist, creates a new cache dictionary

    Parameters
    ----------
    None

    Returns
    -------
    cache_dict (dict): the cache variable
    '''
    try:
        cache_file = open(CACHE_FILENAME, 'r')
        cache_contents = cache_file.read()
        cache_dict = json.loads(cache_contents)
        cache_file.close()
    except:
        cache_dict = {}

    return cache_dict

def save_cache(cache_dict):
    '''
    Saves the current state of the cache to disk

    Parameters
    ----------
    cache_dict (dict): dictionary to write to disk

    Returns
    -------
    None
    '''
    dumped_json_cache = json.dumps(cache_dict, indent=2)
    fw = open(CACHE_FILENAME,"w")
    fw.write(dumped_json_cache)
    fw.close()

# %%
def get_source_scrollable(url):
    """
    Gets the page source for a site that requires multiple scrolls but has a finite end
    """
    CACHE_DICT = open_cache()
    if url in CACHE_DICT.keys():
        print('Fetching from cache...')
        return CACHE_DICT[url]
    else:
        print('Making new headless browser')
        # Setup headless chromedriver
        chrome_options = Options()
        chrome_options.add_argument("--headless")
        driver = webdriver.Chrome(CHROMEDRIVER_PATH, options=chrome_options)
        driver.get(url)
        # Get scroll height
        last_height = driver.execute_script("return document.body.scrollHeight")

        while True:
            # Scroll down to bottom
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

            # Wait to load page
            time.sleep(SCROLL_PAUSE_TIME)

            # Calculate new scroll height and compare with last scroll height
            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
            last_height = new_height

        html = driver.page_source
        CACHE_DICT[url] = html
        driver.close()
        save_cache(CACHE_DICT)
        return html

# %%
def request_with_cache(url):
    if url in CACHE_DICT.keys():
        print('Fetching from cache...')
        return CACHE_DICT[url]
    else:
        print('Fetching new data...')
        r = requests.get(url)
        html = r.text
        CACHE_DICT[url] = html
        save_cache(CACHE_DICT)
        return html

# %%
def get_top_track_links(html):
    soup = BeautifulSoup(html, "html.parser")
    # Links to top artists in genres
    links = soup.find('div', {'class': 'chartTracks'}).find_all('a', href=re.compile('^/[^/]*$'))
    return list(set(links))

def get_artist_stats(link):
    full_path = f"https://soundcloud.com{link['href']}"
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36',
                'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8'}
    r = requests.get(full_path, headers=headers)
    soup = BeautifulSoup(r.text, "html.parser")
    try:
        x = soup.find_all('script')[9].string.split('= ')[1].strip('][').split('{')[-4].split(',')
        stat_dict = {}
        for val in x[6:30]:
            kps = val.split(':')
            stat_dict[kps[0].strip('"')] = kps[1].strip('"')
        print(f"Success for {link['href']}")
        return stat_dict
    except:
        print(f"Issue with {link['href']}")

# %%
url = "https://soundcloud.com/charts"
html = request_with_cache(url)
soup = BeautifulSoup(html, "html.parser")
final_list = []
# Links to all genres (e.g. alternativerock, dancehall)
category_links = soup.find_all('a', href=re.compile("^(/charts/top)((?!all-).)*$"))

for category_link in category_links:
    full_path = f"https://soundcloud.com{category_link['href']}"
    print(f"{full_path}")
    html = get_source_scrollable(full_path)
    links = get_top_track_links(html)
    for link in links:
        stat_dict = get_artist_stats(link)
        if stat_dict:
            final_list.append(stat_dict)
# Out:
# Fetching from cache...
# https://soundcloud.com/charts/top?genre=alternativerock
# Fetching from cache...
# Issue with /smithsmithmusic
# Success for /currentjoys
# Success for /sufjan-stevens
# Success for /beartrapsound
# Success for /jorgehl-1
# Success for /teen-suicide
# Success for /panicatthedisco
# Success for /dandelionhands
# Issue with /fearlessrecords
# Success for /vancejoy
# Success for /greenday
# Success for /plwushii
# Issue with /adam-woodard
# Success for /title-fight
# Success for /fayewebster
# Success for /beachbunnymusic
# Success for /ajrbrothers
# Success for /fueled_by_ramen
# Success for /phoebebridgers
# Success for /lil_peep
# Success for /kaiyo-986878357
# Issue with /mitskiofficial
# Success for /user-258835843
# Success for /manchesterorchestra
# Success for /thisisduster
# Success for /tealoversunite
# Success for /invoguerecords
# Success for /mac-demarco-official
# Issue with /hopelessrecords
# Success for /tobiasdray
# Success for /machinegunkelly
# https://soundcloud.com/charts/top?genre=ambient
# Fetching from cache...
# Success for /meditative-mind
# Success for /soothingrelaxation
# Issue with /sam_relaxation
# Success for /rainsoundswhitenoise
# Issue with /symphocat
# Success for /babywhitenoise
# Success for /diegoasturias
# Success for /user9175165
# Success for /thechilloutzoneuk
# Success for /chilledsad
# Issue with /therhythmtree
# Success for /kait-con-botas
# Success for /minecraftwizards
# Success for /rainforsleep
# Success for /wavesourcemusic
# Success for /jxhn-boii
# Success for /pan_hq
# Success for /scizzie
# Success for /edmond104
# Success for /sean-t-phan
# Success for /deepsleepbrownnoise-music
# Issue with /relaxmusic-3
# Issue with /fionajoyhawkinsmusic
# Success for /galimatias
# Issue with /justmusiclabel
# Success for /lakeyinspired
# Success for /nicholas-smith-pianist
# Issue with /relaxdaily
# Success for /relaxing-white-noise
# Success for /mindsoulmedia
# Success for /stardustvibes
# Issue with /rjsfoundsounds
# Success for /whitenoisebabysleep
# Issue with /felixblume
# Success for /relaxing_guru
# Success for /spiritualmoment
# Success for /user-908929543
# Issue with /wonderful-lullabies
# Success for /oceansoundswhitenoiseforsleep
# https://soundcloud.com/charts/top?genre=classical
# Fetching from cache...
# Success for /jack-villano-villano
# Success for /user-910978885
# Success for /sleepyheadz-music
# Success for /fernando-emmanuel-315127619
# Success for /ludovicoeinaudi
# Success for /vulturess
# Success for /user-265947656
# Success for /sangwoosimp
# Issue with /glennmorrison
# Success for /939932
# Success for /uguru-music
# Success for /bonifansius
# Success for /flatsound-music
# Success for /tatiana-zoghi
# Success for /user-185943417
# Success for /user-410725016
# Success for /blaketothefuture
# Success for /user-833905282
# Success for /the86thfloor
# Success for /ellabella-zazueta
# Success for /paroquia-de-nossa-senhora-da-soledade
# Success for /erik-satie
# Success for /lullaby_world
# Success for /raphael-novarina
# Issue with /christelveraart
# Issue with /chad-lawson
# Success for /etienne-cassani
# Success for /johnas-sak
# Success for /bryantcaleb
# Success for /classical-piano-hits
# Success for /bobbysworldchildcare
# Success for /ocalocal
# Success for /kate-dion
# Success for /pedro_bernardi
# Success for /lilypichu
# Success for /apenguinexpert
# Success for /classical-music-playlist
# Issue with /wonderful-lullabies
# Success for /iziah-plays
# Success for /dellrenewed
# Success for /maiya-hershey
# Success for /claude-debussy
# Success for /reminiscience
# Success for /narutoroleplayg
# https://soundcloud.com/charts/top?genre=country
# Fetching from cache...
# Success for /tylerhubbardofficial
# Success for /sam-hunt-official
# Success for /regionalmexicanochingon
# Success for /jordandavisofficial
# Success for /warren-zeiders-music
# Success for /mysticphonk
# Issue with /parkermccollum
# Success for /theindependentrapuploader
# Success for /zacbrownband
# Success for /raynejohnsonmusic
# Success for /baileyzimmerman-music
# Success for /flagaline
# Success for /koewetzel
# Success for /elvieshane
# Success for /diplo
# Success for /user811955751
# Success for /bretteldredge_1632905139754
# Success for /nextwaltz
# Success for /lecade-music
# Success for /thekiddg
# Success for /tylerchilders
# Success for /davidmorrisofficial
# Success for /loganmichael-music
# Success for /codyjohnsonband
# Success for /chris-stapleton-music
# Success for /morgan-wallen
# Success for /official-luke-bryan
# Success for /blakeshelton
# Success for /secret-service-862007284
# Success for /achane
# Success for /jasonaldean
# Success for /codyjinksmusic
# Issue with /rileygreen-music
# https://soundcloud.com/charts/top?genre=danceedm
# Fetching from cache...
# Success for /max-c-455673189
# Success for /octobersveryown
# Success for /ninjasmart
# Success for /dionysusdubz
# Success for /riesieboy50
# Success for /cleanbandit
# Success for /lfsystem
# Success for /jayke-mac
# Success for /djsnake
# Success for /andonismusic
# Success for /anilifts
# Success for /stratisphere_productions
# Success for /bigbootiemix
# Success for /ahhmusicofficial
# Success for /user-425507471
# Success for /weverton-melo-427991446
# Success for /riley-evans
# Success for /bakimp4
# Success for /user-668129638
# Success for /mrowie
# Success for /user-547054014
# Success for /venkomusic
# Success for /karma-20967029
# Success for /dom-livez
# Success for /m1611
# Success for /m2nok
# Issue with /illeniumofficial
# Issue with /davidguetta
# Success for /kiraly_gergo
# Success for /aidan-reed-696611195
# Success for /elizarosemusic
# Success for /maulbrah
# Success for /user-74120535
# Success for /maximus-ford
# https://soundcloud.com/charts/top?genre=dancehall
# Fetching from cache...
# Success for /lexxredd
# Success for /xodevonte
# Success for /eric-porter-6
# Issue with /addeinstrumentals
# Success for /djozz826
# Success for /reggaedancehall
# Issue with /1priincemuzik
# Success for /travisworldmusic
# Success for /chrisfusion
# Success for /seanpaul2
# Success for /yardhyperadio
# Success for /dancehallofwar
# Success for /vybz-kartel-official
# Success for /doveymagnumofficial
# Success for /djjoeltjamkam
# Success for /skillibeng
# Success for /wbt-empire
# Success for /djholup
# Success for /mywidy
# Success for /roodyroodboy
# Success for /djkurtriley
# Success for /21sthapilos
# Issue with /kestheband
# Success for /kevinlyttleofficial
# Success for /vp_records
# Success for /dj-miltonja
# Success for /mixpak
# https://soundcloud.com/charts/top?genre=deephouse
# Fetching from cache...
# Success for /djdropg
# Success for /dj-regard-1
# Success for /alexcruz
# Issue with /noraenpure
# Success for /deepmixnation
# Issue with /vijayandsofia
# Success for /lo-freq-1
# Success for /denniskruissen
# Success for /mtarecords
# Success for /brdly
# Success for /discolines
# Success for /thelaw1212
# Issue with /m-we-1
# Success for /shinemusic
# Issue with /edxmusic
# Success for /kavverhouzer
# Issue with /turborecordings
# Success for /user-675098118
# Success for /dj-mike-richards
# Success for /prettypink
# Success for /anjunadeep
# Success for /selectedbase
# Success for /tech-me-house
# Issue with /stevevoidmusic
# Success for /mahmut-orhan
# Success for /noisysoundss
# Success for /miamibeats
# Success for /dillonfrancis
# Success for /auxlondon
# Issue with /ahmet-kilic
# Success for /flaurese
# Success for /djsilvium
# Success for /mixfeed
# Success for /deependmusic
# Success for /fabio-ruffinoni
# https://soundcloud.com/charts/top?genre=disco
# Fetching from cache...
# Success for /slawomir-music
# Success for /lipps-inc-official
# Success for /futuresocietycollective
# Success for /djmacklong
# Issue with /piedpiper
# Success for /fvuk
# Success for /digital-visions
# Success for /lpereira7
# Success for /village-people
# Success for /poolside
# Success for /pjsteman
# Issue with /michaeljackin
# Success for /aritusmusic
# Success for /segue-1
# Success for /mistajam
# Success for /digital-visions-replay
# Success for /mix80s
# Success for /gilles-dumontet
# Issue with /evenfunkier
# Success for /donna-summer-official
# Success for /pokert
# Success for /sayyesrecords
# Issue with /gloria-gaynor
# Success for /hearken-ent
# Success for /dj-airwolf
# Success for /dj-miltonja
# Success for /0600-records
# Success for /time2flyrecords
# Success for /beegees
# Success for /hairoshi
# https://soundcloud.com/charts/top?genre=drumbass
# Fetching from cache...
# Issue with /dollarboyz
# Success for /pilotrecordsuk
# Issue with /111loggedin
# Success for /deltaheavyuk
# Success for /monstercat
# Success for /drumandbassarena
# Success for /pleasedonttellmymoms
# Success for /ukf
# Issue with /delamoonmusic
# Success for /sharkastic
# Success for /1985music1985
# Issue with /thewiddfam
# Success for /mackygee
# Success for /biometrix
# Success for /farrahsounds
# Success for /nocopyrightsounds
# Success for /nfract
# Success for /phantasy
# Success for /visionrecordings
# Issue with /simmeredm
# Issue with /gray_music
# Success for /slycd_dubs
# Issue with /madukdnb
# Success for /djdieselofficial
# Success for /photon-snake
# Issue with /elevaterecordsuk
# Success for /subfocus
# Success for /user-110436589
# Issue with /mistatrick
# Issue with /georgieriot
# Success for /harmful-logic
# Success for /sewerslvt
# Success for /sprucednb
# Success for /liquidbass
# Success for /undehfined
# Success for /deeptrip-music
# Success for /r3dx
# Success for /nurtheon
# Success for /kreuzdnb
# Success for /blankemusicau
# https://soundcloud.com/charts/top?genre=dubstep
# Fetching from cache...
# Success for /bernzikial
# Success for /dubstepgutter
# Success for /woolimusic
# Success for /dackjaniels
# Success for /dubstep
# Success for /spagheddy
# Success for /slanderofficial
# Success for /ganjawhitenight
# Success for /space-laces
# Success for /carbin-official
# Success for /excision
# Success for /long_arms
# Success for /zedsdead
# Success for /seven-lions
# Success for /musicbytvboo
# Success for /m3nacemusic
# Success for /adventureclub
# Success for /virtual-riot
# Success for /killuminati26
# Issue with /dirtysnatcha
# Success for /wakaan
# Success for /flux-pavilion
# Success for /morbeato
# Success for /skrillex
# Success for /subtronics
# Issue with /ironhidedubstep
# Success for /caspaofficial
# Issue with /ophelia_records
# Success for /tape-b-official
# Success for /not-for-money
# Issue with /weareriot
# Success for /jkylxhyde
# Success for /nimda_uk
# Success for /nghtmre
# https://soundcloud.com/charts/top?genre=electronic
# Fetching from cache...
# Success for /slvg420
# Success for /oscarlangmusic
# Issue with /atlanticrecordsrussia
# Success for /prod-poob
# Success for /4k73ww-5722155
# Success for /pogomix
# Success for /mrkitty_sc
# Success for /kutemane
# Success for /lilswervoojr
# Success for /auroraaksnes
# Success for /axxturel
# Success for /lunnsong
# Success for /memo_boy
# Success for /thermonada
# Success for /instupendo
# Success for /umbasap
# Success for /home-2001
# Success for /speedmasterrecords
# Success for /tame-impala
# Success for /kronopage
# Success for /kslv_noh
# Success for /yvetzal
# Success for /mcorsen
# Success for /mistxplaya
# Success for /staysold
# Success for /vezal
# Success for /hensonnmusic
# Success for /pastelghost
# Success for /dayglowmusic
# Success for /5w3
# Success for /dxnnyfxntom
# Success for /kxnvra
# Success for /bacleo
# Success for /yosoyharmless
# Success for /astrophremix
# Success for /noahkittinger
# Success for /dreamscapeyt
# Success for /vierrecloud
# Success for /slowymane
# Success for /prodbydxrk
# Success for /bornsmusic
# Success for /playaphonk
# Success for /crim3s
# Success for /antwoine-95747738
# Success for /itsjvke
# Success for /natekiserv
# Success for /crystal-castles
# https://soundcloud.com/charts/top?genre=folksingersongwriter
# Fetching from cache...
# Success for /tomrosenthal1
# Issue with /ruthbofficial
# Success for /colterwallofficial
# Success for /symlmusic
# Success for /lullaby-babies
# Success for /hashtagcatie
# Success for /boniver
# Success for /iameden
# Success for /winteraid
# Success for /cigarettesaftersex
# Success for /stephensanchezofficial
# Success for /tracychapmanofficial
# Success for /natalietaylor
# Success for /mamadoutherose
# Success for /semataryy
# Success for /ansonseabra
# Success for /iamtomwalker
# Success for /clintonkane
# Success for /modesaboutme
# Success for /asthmatickitty
# Success for /edithwhiskers
# Success for /lvjy
# Success for /leith-ross
# Issue with /deanlewisofficial
# Success for /tylerchilders
# Success for /user-448329515
# Success for /catburnsmusic
# Issue with /ringlefinchuk
# Success for /sarakays
# Success for /sleepingatlast
# Success for /the-oh-hellos
# Success for /achane
# Success for /mollykatekestner
# Issue with /stickfigure
# Success for /jubyphonic-p
# Success for /tltombstone
# Success for /claire-b-27596122
# Success for /adrian-bliss-2
# https://soundcloud.com/charts/top?genre=hiphoprap
# Fetching from cache...
# Success for /internetmoneyrecords
# Success for /icespiceee
# Success for /rodwave
# Success for /digital-trapstars
# Success for /lilmabu
# Success for /navmusic
# Success for /kodak-black
# Success for /futureisnow
# Success for /gherbo
# Success for /pnbrock
# Success for /nba-youngboy
# Success for /liltecca
# Success for /liltjay
# Success for /badbunny15
# Success for /lilyeat
# Success for /jeleelyussuf
# Success for /drokenji
# Success for /nardo-wick
# Success for /pierrebourne
# https://soundcloud.com/charts/top?genre=house
# Fetching from cache...
# Success for /sebastiansc
# Success for /lightbassreal
# Success for /spuriao
# Success for /djpeachmusic
# Success for /housemusic
# Success for /stixgod
# Success for /djgetdown
# Success for /trxmell4-4
# Success for /timgunter
# Success for /chyxzzz
# Success for /menok00
# Success for /njcarlyk
# Success for /defectedrecords
# Success for /steveaoki
# Success for /fish-tales
# Success for /durdenhauer
# Success for /stapiegun
# Success for /v1sxge
# Success for /mcorsen
# Success for /dzhin-xo
# Success for /razihelmusic
# Success for /calvinharris
# Success for /user-416967058
# Success for /hugo-garcia-389613577
# Issue with /3beat
# Issue with /equalizermx
# Issue with /itsthewestend
# Success for /wudaddy
# Success for /maraudamusic
# Success for /imminentnetwork
# Success for /fruchtpommes1
# Success for /max-karlsson-388070498
# Success for /sickkuntsounds
# Success for /mhmddewedar
# Success for /solow-1
# Success for /stardust47685
# Success for /deerockmusic
# Success for /crucialbrah
# Success for /repopulatemars
# Issue with /fwxx
# Success for /asemanual
# Success for /celestial_sleepyhead
# Success for /fxrr-music
# Success for /eyezhateu
# Success for /b_webs
# Success for /user-801855275
# Success for /squeaky-beatz
# Success for /user-420828674
# https://soundcloud.com/charts/top?genre=indie
# Fetching from cache...
# Success for /user-578957262
# Success for /d4vddd
# Success for /lykkeli
# Success for /oddsweetheart
# Success for /iameden
# Success for /ditchdays-music
# Success for /cherublamusica
# Success for /capturedtracks
# Success for /cigarettesaftersex
# Success for /youngthegiant
# Success for /boy-pablo777
# Issue with /wichita-recordings
# Issue with /tonesandi-music
# Success for /seafretofficial
# Success for /neffexmusic
# Success for /sky_kitten
# Success for /guardinmusic
# Success for /catluvr01
# Success for /rosalinnmusic
# Success for /eyedress
# Success for /needlefeet
# Success for /eurythmics-official
# Success for /bennettcoast
# Success for /vincentmcgee
# Success for /stephezzy-1
# Success for /deccoooo
# Success for /whoismgmt
# Success for /no-vacation
# Success for /the-sarcastic-ashole
# Success for /vanillagorillaband
# Success for /yeaabk
# Success for /anna-dority
# Success for /deyazwb
# Success for /ahmedalnajjar93
# https://soundcloud.com/charts/top?genre=jazzblues
# Fetching from cache...
# Success for /louisarmstrongofficial
# Issue with /rob-noordeloos
# Success for /user-386239686
# Success for /emanuel-joseph-whiteman
# Success for /typicalayden-x
# Success for /yung-mattress
# Success for /groverwashingtonjr
# Success for /milesdavissonymusic
# Success for /juan-gabriel-13909959
# Success for /user-816492787-683502295
# Success for /king-floyd-official
# Success for /yuripinheiro
# Success for /user-646666166
# Success for /mxmtoon
# Success for /umit-basyigit
# Success for /harry-james-official
# Success for /salehfilmz
# Success for /frank-sinatra
# Success for /user-788747879
# Success for /jwilborn
# Success for /roy-ayers-ubiquity
# Success for /bobbymcferrinmusic
# Success for /connorspiotto
# Issue with /cyrilleaimee
# Success for /herbalpert
# Success for /mattblock-music
# Success for /salma-yahya-6
# Success for /tommydorsey
# Success for /louis-prima-official
# Success for /qu-nh-kh
# Success for /shredder-games
# Success for /mema_72
# Success for /yael-wolfenson
# Success for /user-975691885
# Success for /sapphire_mjw
# Success for /weldonirvine
# Success for /mirage91
# Success for /bobby-caldwell-official
# Success for /hell-hound10
# Success for /rodesnanda
# Success for /robertglasper
# Success for /billie-holiday-official
# Success for /mukunda-mtandari
# Success for /a-seneca
# https://soundcloud.com/charts/top?genre=latin
# Fetching from cache...
# Success for /carinleon
# Success for /djmtwice
# Success for /alex-macias-325125665
# Success for /user-528883814
# Success for /user-156449902
# Success for /djmauryoficialmezclu
# Issue with /edicionespecial
# Success for /the-trap-house
# Success for /luisrconriquez
# Issue with /sonidogodzila
# Success for /djalfonzin
# Success for /portediferente
# Success for /djtitonortenas
# Success for /brian-l-472359922
# Success for /user-63975080-303558080
# Success for /natanaelcano
# Success for /jaywheelerpr
# Success for /discomovilhuapachoso
# Success for /juniorh-music
# Success for /grupofirme
# Success for /grupomarcaregistradaofficial
# Success for /elcrazydallas
# Success for /zion-lennox-official
# Success for /grupoarriesgado-music
# Success for /edgardonunez-music
# Success for /efectoelegante
# Success for /kaliuchis
# Success for /anuel2blea
# Success for /urban-latino
# Success for /elfantasma-music
# Success for /edenmunoz-music
# Success for /losk-bros
# Success for /jrtorres-music
# Success for /user-611367086
# https://soundcloud.com/charts/top?genre=metal
# Fetching from cache...
# Issue with /renatoluis-ferreira
# Success for /thebestofhardmetal
# Success for /pantera
# Success for /type-o-negative
# Success for /officialshizumaru
# Success for /saliva
# Success for /haris-adnan
# Success for /will-dubois
# Success for /craigxen
# Success for /red-bull-records
# Success for /user-789507586-363401266
# Success for /derivakat
# Success for /dubstepmaniac007
# Issue with /fearlessrecords
# Success for /viterom
# Success for /beyondunbroken
# Success for /thebandghost
# Success for /hikariultra
# Success for /pieceoflembas
# Success for /semataryy
# Success for /jean-francois-kryl
# Success for /caocao2361
# Success for /roadrunnerrecords
# Success for /roadrunner-usa
# Success for /metal-head0-1
# Success for /five-finger-death-punch-official
# Success for /dm-dokuro
# Success for /disturbed1
# Success for /blueholeproject
# Success for /ic3peak
# Success for /dioofficial
# Success for /officialmetallica
# Success for /bad-omens
# Success for /ffxivmusic
# Success for /slipknot
# https://soundcloud.com/charts/top?genre=piano
# Fetching from cache...
# Success for /soothingrelaxation
# Issue with /starwarspunk
# Success for /aouysdgfahsbdfiwegdfsesuf
# Success for /yvpoipoi
# Issue with /charlessegalmusic
# Success for /longtaow
# Success for /soothingmusicensamble
# Success for /efim-er
# Success for /myuu
# Success for /larryfisherman
# Success for /newagemusicplanet
# Success for /reynah_3
# Issue with /davidhollandsworth
# Issue with /juansanchezcomposer
# Success for /krisuchillstep
# Success for /crawford-chng
# Success for /marijanmusic
# Success for /arwindpianist
# Success for /gobaid
# Success for /protegemoi-1
# Success for /dawelocklear
# Success for /squeakep
# Success for /jurrivh
# Issue with /relaxdaily
# Success for /freemondo88
# Success for /awfulpianosound
# Success for /dm-dokuro
# Success for /midimuppetofficial
# Success for /alexa-gamer123
# Success for /steffanspianocovers
# Issue with /andrej-zatkalik-1
# Success for /y39vlpz6tx6x
# Success for /tenlki
# Success for /rustleteh
# Success for /mae-lee-984068236
# Success for /focu-dengel
# Success for /pianomusicchannel
# Success for /1lychee
# Issue with /musicmike512
# Success for /hyrix-official
# Success for /sharieingente
# Success for /bennymartinpianist
# Success for /stephanjoesten
# Success for /delialah-el-atwi
# Success for /oriensi
# https://soundcloud.com/charts/top?genre=pop
# Fetching from cache...
# Success for /ritt-momney
# Success for /d4vddd
# Success for /ivancornejo
# Success for /lordawall
# Success for /steevlacy
# Success for /angel-perez-109659204
# Success for /eslabonarmado
# Success for /willisband
# Success for /kxllswxtch
# Success for /mareux
# Success for /jahseh-onfroy
# Success for /omarapollo
# Success for /rihanna
# Success for /thewaltersband
# Success for /billieeilish
# Success for /ulises-hernandez-658521041
# Success for /claralasan
# Success for /vacationsfanclub
# Success for /yahritza
# Success for /men-i-trust
# Success for /sonder
# Success for /grupomarcaregistradaofficial
# Success for /tv-girl
# Success for /eyedress
# Success for /bennyblanco
# Success for /pinkpantheress
# Success for /tylerchilders
# Success for /yotclub
# Success for /mac-levine
# Success for /jojiofficial
# Success for /keltiey
# Success for /dannylux
# Success for /user-572069395
# Success for /thekidlaroi
# Success for /patrick_watson
# Success for /gesaffelstein
# Success for /gotye
# Success for /joyagain
# Success for /itsjvke
# Success for /beachhouse
# Success for /grentperez
# Success for /lianaflores
# https://soundcloud.com/charts/top?genre=rbsoul
# Fetching from cache...
# Success for /troyalmusic
# Success for /roywoodsofficial
# Success for /yung-bleu
# Success for /user-777274585
# Success for /steevlacy
# Success for /giveon
# Success for /szababy2
# Success for /summerwalker
# Success for /akon
# Issue with /laytongreene
# Success for /munilong
# Success for /trippie-hippie-2
# Success for /amaru-son
# Success for /childish-gambino
# Success for /torylanez
# Success for /dontoliver
# Success for /lambo4oe
# Success for /yk-osiris
# Success for /brentfaiyaz
# Success for /theweeknd
# Success for /kaliuchis
# Success for /temsbaby
# Success for /thegreatkhalid
# Success for /jojiofficial
# Success for /brysontiller
# Success for /lawsyy
# Success for /amalaofficial
# Success for /milajofficial
# Success for /luckydaye
# Success for /chris_brown
# Success for /jhene-aiko-1
# Success for /partyomo
# Success for /danielcaesar
# Success for /summrs
# Success for /ilham_official
# https://soundcloud.com/charts/top?genre=reggae
# Fetching from cache...
# Success for /skeng-music
# Success for /armaniisyg
# Success for /spice-official
# Issue with /reggaeroast
# Success for /chickomusic
# Success for /ingroovesmarketing
# Success for /young_revus
# Success for /kranium1
# Success for /bob-marley-the-wailers
# Success for /seggyinkk
# Success for /bayka-sc
# Success for /vybz-kartel-official
# Success for /gyptian-official
# Success for /shenseea
# Issue with /popcaanmusic
# Success for /jefffullyauto
# Success for /power-punch-sound
# Success for /yara-yussef
# Success for /skillibeng
# Success for /jadakingdom
# Success for /fiji-official
# Success for /alkalineofficial
# Success for /squashofficial
# Success for /hoodcelebrityy
# Success for /shaneoofficial
# Success for /ryginking
# Success for /dextadaps
# Success for /bobmarley876
# Success for /stefflon-don-1
# Issue with /stickfigure
# Issue with /sammielz
# Success for /10tik
# Issue with /damianmarley
# https://soundcloud.com/charts/top?genre=reggaeton
# Fetching from cache...
# Success for /djprivateryan
# Success for /user-670338694
# Success for /javi-cases
# Success for /mato1319
# Issue with /farrukooficial
# Success for /user-736644952
# Success for /nelaionmusic
# Success for /reggaeton
# Success for /trap-planeta
# Success for /luis_15_blin
# Success for /user-564549918
# Success for /luzonicent
# Success for /designerboyoficial
# Success for /dj_harold89
# Success for /lennytavareztm
# Success for /fuegomusica
# Success for /laesenciadelgenero
# Success for /duttypleasures
# Success for /markdesignofficial
# Success for /bavikon
# Success for /majorlazer
# Success for /brunotorresremixes6
# Success for /kora-dj-guaytambo-dj
# Success for /urbans-music-pr
# Success for /dj-nir-maimon
# Issue with /ozunapr
# Success for /babyrastagringo
# Success for /thepunchlinetv
# Success for /rd-urbansmusic
# Success for /anuel2blea
# Success for /juan-diego-rodriguez-o-f-i-c-i-a-l-f-b
# Success for /daddy-yankee-official
# Success for /djtmarqnew
# Success for /plena507
# Success for /ema-zambrana-perez
# Success for /richardbeatz
# Success for /user-79349876
# Success for /djcuervorey
# Success for /flakodinastiahuitzil
# Success for /ssast-an-pizarro
# https://soundcloud.com/charts/top?genre=rock
# Fetching from cache...
# Success for /beachweathermusic
# Success for /exulansism
# Success for /gravityisfake
# Success for /wearecafune
# Issue with /the-rare-occasions
# Success for /nirvana
# Issue with /suki_waterhouse
# Success for /nikotinoscigi
# Success for /nart-kelmendi
# Success for /cigarettesaftersex
# Issue with /melodic-records
# Success for /jahseh-onfroy
# Issue with /user-422076658
# Success for /linkin_park
# Success for /vundabar
# Success for /ally-232118998
# Success for /user-159269827
# Success for /dominic-kabeche-523592113
# Success for /foofighters
# Success for /strawberryguy
# Success for /user-96306578
# Success for /tdubbs26
# Success for /vacationsfanclub
# Success for /lewcci
# Success for /beachbunnymusic
# Success for /unharmedofficial
# Success for /eyedress
# Success for /user-592797091
# Success for /coyotetheory-music
# Success for /matt-maltese
# Success for /skylineguy
# Success for /lildvrkie
# Success for /delonte-montague
# Success for /thisisduster
# Success for /shesoka
# Success for /user-7345727
# Success for /mac-demarco-official
# Success for /officialmetallica
# Success for /deftones_official
# Success for /user-991428509
# Success for /dharma-i-monster
# Success for /deb7rh
# https://soundcloud.com/charts/top?genre=soundtrack
# Fetching from cache...
# Success for /oliviarodrigo
# Success for /bleach_ost
# Success for /amaarae
# Issue with /andy-grammer-official
# Success for /snoopdogg
# Success for /nicholasbritell
# Success for /lana-del-rey
# Success for /kate-bush-official
# Success for /ericdoa
# Success for /dianeguerrero-music
# Success for /jalphonsenicholson
# Success for /labrinth
# Success for /pieropiccioniofficial
# Success for /extrafical-yt
# Success for /luvenchanting
# Success for /megan-thee-stallion
# Success for /samuelkimmusic
# Issue with /daniel-j-rocha
# Success for /tobyfox-music
# Success for /tupe-sauaso
# Success for /lightningsplash
# Success for /cudderland
# Success for /migosatl
# Success for /sofia-carson
# Success for /uiceheidd
# Success for /charlotteslawrence
# Success for /honeyy-draws
# Success for /sleepingatlast
# Success for /stevenuniverse-music
# Success for /angrysausage
# Success for /zacky-san
# Success for /jucee-froot
# Success for /haretonsalvanini
# Success for /halseymusic
# Success for /pharrellwilliams-official
# Success for /music-from-the-void
# Success for /jessicadarrow
# Success for /4townfromdisneyandpixarsturningred
# Success for /carolinagaitan-music
# Success for /duckwrth
# https://soundcloud.com/charts/top?genre=techno
# Fetching from cache...
# Success for /wearethebraveofficial
# Success for /kou_desu
# Success for /overmono
# Success for /angerzam_official
# Issue with /laytongiordani
# Success for /mixmag-1
# Success for /drumcode
# Success for /djblyatman
# Success for /marc-cochrane-2
# Success for /cheapex
# Success for /stanchrist
# Success for /monstersofcore
# Success for /kurrupt_recordings_hard
# Success for /mark-dekoda
# Success for /smashrecordshc
# Success for /boris-brejcha
# Issue with /shouseshouseshouse
# Success for /trippycode
# Success for /goreshit
# Success for /kerbela
# Success for /adambeyer
# Success for /everyoneonacid
# Success for /user-728279380
# Issue with /tears-of-fury
# Success for /thefinesttechno
# Success for /monolink
# Success for /wearemindflux
# Issue with /imwaleed
# Success for /judebradshaw
# Success for /filthonacid
# Success for /technogermany
# Success for /running_clouds
# Success for /s3rl
# Success for /user-112658712
# Success for /vcldj
# Success for /shxdow_techno
# https://soundcloud.com/charts/top?genre=trance
# Fetching from cache...
# Success for /spiritualmudra
# Success for /jasonrossofficial
# Success for /liav-ben-yakar
# Success for /rainbowtripmusic
# Success for /dashberlin
# Issue with /psynationradio
# Success for /cosmicgateofficial
# Issue with /garethemery
# Issue with /tritonalmusic
# Success for /cerclelive
# Success for /arminvanbuuren
# Success for /markusschulz
# Success for /toddz999
# Success for /ephesis_music
# Success for /bryankearney
# Success for /christopherlawrence
# Success for /theviicrew
# Issue with /aboveandbeyond
# Success for /jdifier
# Success for /enhancedprogressive
# Issue with /andrewrayel
# Success for /babalos
# Success for /universoparalellofestival
# Success for /vocaltrance4ever
# Success for /solarstone
# Issue with /nettwerkmusicgroup
# Success for /f1nneon
# Issue with /vinivicimusic
# Success for /anjunabeats
# Issue with /john00fleming
# Issue with /yourunity
# Success for /wandw
# Success for /armadamusic
# Success for /dj_vulcan
# https://soundcloud.com/charts/top?genre=trap
# Fetching from cache...
# Success for /lacuna
# Success for /revokesounds
# Success for /alltrapnation
# Success for /slanderofficial
# Success for /user-803067878
# Success for /tranqsivk
# Success for /greencookie
# Success for /lucianofficial
# Success for /luzonicent
# Success for /triptropmusic
# Success for /gordoszn
# Success for /lennytavareztm
# Success for /sssshawnnnn
# Success for /mootzygold
# Success for /v1sxge
# Success for /teamtaj
# Success for /trapmusichd
# Success for /bakadimusic
# Success for /losdurostv
# Success for /marcus-mj
# Success for /kxa-1
# Success for /rlgrime
# Success for /holytrapmusic
# Success for /morethanrecs
# Success for /jikay
# Success for /nickraymondg
# Success for /kevin-torres-189155898
# Success for /rayvolpemusic
# Issue with /tribaltrapmusic
# Success for /lasustanciaurbana
# Success for /hucci
# Success for /patrickrezavip
# Success for /traphouselatino
# Success for /arman-cekin-remix
# Success for /itstrapnetwork
# Success for /osiasmusic
# Success for /crankdatmusic
# Success for /ssast-an-pizarro
# Success for /nghtmre
# Success for /timgunter
# https://soundcloud.com/charts/top?genre=triphop
# Fetching from cache...
# Issue with /erichiltonmusic
# Success for /radio-citizen
# Success for /thebluesquare
# Success for /annursidney
# Success for /locirecords
# Issue with /architektur
# Success for /trip-hop-nation
# Success for /notannigres-music
# Success for /slamhaus
# Success for /thelofihiphop
# Success for /littlepeoplemusic
# Success for /shponglemusic
# Success for /j-rawls
# Success for /mrmoods
# Success for /lunemusique
# Success for /shawnleespingpongorchestra
# Success for /patrick-duvignacq
# Issue with /dj-surgeon
# Issue with /8dpromo
# Issue with /desertdwellers
# Success for /testshotstarfish
# Issue with /jenova-7
# Success for /vpd
# Success for /shawnleeofficial
# Issue with /shamansdream
# Success for /random-rab
# Issue with /ultimae
# Success for /peteatlas
# Success for /kb-andras
# Issue with /getting-deeper
# Success for /thieverycorporation
# Success for /s1xmusic
# https://soundcloud.com/charts/top?genre=world
# Fetching from cache...
# Success for /trippieredd
# Success for /ysnflow
# Success for /jasmine-macdonald-356972534
# Success for /emiliano-m-mendez
# Success for /newjeans-music
# Success for /zdes_holodno
# Success for /509sicario
# Success for /apichit-ketarun-234302450
# Success for /mavinrecords
# Success for /user-403653203-554463745
# Success for /user-113770268
# Success for /jovensnothere
# Success for /user-163044006
# Success for /wesleeee
# Success for /th3plugradio2
# Success for /arkivaun
# Issue with /maleekberry
# Success for /airitout-juju-flame
# Success for /twice-57013
# Success for /zeckihmm
# Success for /fireboydml
# Success for /djspinall
# Success for /zafira-xp
# Success for /alamortatl
# Success for /scumgang6ix9ine
# Success for /tee-grizzley
# Success for /heisrema
# Success for /euil
# Success for /propxqity-04
# Success for /octobercasket
# Success for /user-410869523
# Success for /user-501399438
# Success for /user-751671231
# Success for /kizzdaniel
# Success for /fuckkkankan
# Success for /liluzivert
# Success for /timotheo-tercero
# Success for /user-80608307
# Success for /rxlzq
# Success for /ic3peakso
# Success for /lx87
# https://soundcloud.com/charts/top?genre=audiobooks
# Fetching from cache...
# Issue with /hachetteaudiouk
# Issue with /penguin-books
# Success for /audiobook-1
# Success for /hay-house
# Success for /penguin-audio
# Success for /hachetteaudio
# Success for /simonschuster
# Success for /hay-house-uk
# Success for /audible
# Success for /harperaudio_us
# Issue with /hodderbooks
# Success for /harperchildrens
# Success for /macaudio-2
# Issue with /harpercollinspublishers
# https://soundcloud.com/charts/top?genre=business
# Fetching from cache...
# Success for /scottbritton
# Success for /thismorningshow
# Success for /theeconomist
# Success for /rvp-builder
# Success for /goldmansachs
# Issue with /addicted2success
# Success for /cambridgejbs
# Success for /chat-with-traders
# Success for /biggerpockets
# Success for /garyvee
# Success for /real-af-with-af
# https://soundcloud.com/charts/top?genre=comedy
# Fetching from cache...
# Issue with /thecomedyfactory
# Success for /earbiscuits
# Success for /thefriendzonepodcast
# Success for /intheconversation
# Success for /themonday-morning-podcast
# Success for /howardstern
# Success for /this-is-not-happening
# Success for /steelpanther
# Success for /lemme-listen
# Success for /kevin-hart
# Success for /coxncrendor
# Success for /yourmomshousepodcast
# Success for /theread
# Success for /tesdpodcast
# Success for /thebrilliantidiots
# https://soundcloud.com/charts/top?genre=entertainment
# Fetching from cache...
# Success for /wxpnfm
# Success for /hot97ny
# Success for /kcoolman
# Success for /billboard
# Success for /redlightspecial
# Success for /sleepycabin
# Success for /joebuddenpodcast
# Issue with /adam-buxton
# Success for /kreayshawn
# Success for /animeme
# Success for /thehiphoplab-1
# Issue with /mrcreepypasta
# https://soundcloud.com/charts/top?genre=learning
# Fetching from cache...
# Success for /liberationinmind
# Success for /billorender
# Success for /gregsreid
# Success for /thepowerofnow_part_1-2
# Success for /matthew-motivation
# Success for /lewishowes
# Issue with /uclsound
# Success for /sanfranciscozencenter
# Issue with /richroll
# Success for /ichripodcasts
# Issue with /davidji
# Success for /lifeleveler
# Success for /rousseben
# Success for /digitalspartan
# Success for /hillsdale-college
# Success for /motivationdays
# Success for /centerpointe
# Success for /maggiedentauthor
# Success for /yaleuniversity
# https://soundcloud.com/charts/top?genre=newspolitics
# Fetching from cache...
# Success for /ewerickson
# Success for /trumpethour
# Success for /radiovision2000
# Issue with /lagammeaumax
# Success for /globovision
# Issue with /shehbazsharif
# Success for /989wclz
# Success for /qudsn
# Success for /arkansastimes
# Issue with /media-roots
# Issue with /hromadske-radio
# Success for /theworld
# Success for /alexelgeniolucas
# Success for /democracynow
# Success for /endtime-ministries
# Success for /pepebillete
# Success for /radioplus-3
# Success for /newzjunky
# Issue with /trumpetdaily
# https://soundcloud.com/charts/top?genre=religionspirituality
# Fetching from cache...
# Success for /samiralbashiri-1
# Success for /redeamigoespirita
# Success for /mrshamiel77
# Success for /ouncil1archive
# Success for /ahmad_alnufais
# Success for /jespadill-channel
# Success for /mlath
# Success for /jalyat
# Success for /entzarnet
# Success for /supresencia
# Success for /massageasmr
# Success for /ftc-church
# Success for /nafahat-media-1
# Success for /mustafahosny
# Success for /dina-a-hadad
# Success for /hania7
# Success for /abu-maism-1
# Success for /woodsedge
# https://soundcloud.com/charts/top?genre=science
# Fetching from cache...
# Success for /listeningearth
# Success for /scifri
# Success for /nasa
# Issue with /startalk
# Issue with /nature-sounds
# Success for /musicofnature
# https://soundcloud.com/charts/top?genre=sports
# Fetching from cache...
# Success for /bettheboard
# Success for /adidasfootball
# Success for /bloody-elbow-presents
# Success for /warriors
# Success for /grandesenlosdeportes
# Success for /soonerscoop
# Success for /fox-team-freedom
# Success for /pregame
# Success for /premier-league
# Success for /nolecast
# Success for /fighterandthekid
# Issue with /nashsportsradio
# Success for /marclawrencepodcast
# Issue with /kxtg-the-bald-faced-truth
# https://soundcloud.com/charts/top?genre=storytelling
# Fetching from cache...
# Success for /wsthewhyfactor
# Success for /hennessy
# Success for /facebookstories
# Success for /truestorytime
# Success for /the-history-of-china
# Issue with /latheatreworks
# Success for /dreamsin8bit
# Success for /themortifiedpodcast
# Success for /radiolab
# Issue with /arte-radio-1
# Success for /snapjudgment
# Issue with /the-story-collider
# Success for /criminalshow
# Success for /nightvaleradio
# Issue with /jonathan-mitchell-1
# Success for /narratively
# Success for /worldaccordingtosound
# Success for /squirrels-stories
# Success for /buttonpoetry
# Success for /mappingtheterritory
# https://soundcloud.com/charts/top?genre=technology
# Fetching from cache...
# Success for /playstation
# Success for /jimquisition
# Success for /techdirt
# Success for /androidcentral
# Success for /yogscast
# Issue with /andre-peschke
# Success for /geekhistorylesson
# Success for /xbox
# Success for /eidosmontreal
# Success for /twit
# Success for /irrationalgames

# %%
[x for x in final_list if x is not None]
# Out:
# []

# %% [markdown]
# # Scraping Data for each Artist

# %%
all_artist_urls = list(final_df['artist_url'])

# %%
def cache_artist_page(artist_url):

    url = artist_url + '/popular-tracks'
    CACHE_DICT = open_cache()
    if url in CACHE_DICT.keys():
        print("Using Cache")
        return CACHE_DICT[url]

    else:
        print("Fetching")
        browser = webdriver.Chrome("/Users/michael/Downloads/chromedriver")
        browser.get(url)
        time.sleep(3)

        page_source = browser.page_source
        CACHE_DICT[url] = page_source
        save_cache(CACHE_DICT)
        return CACHE_DICT[url]

# %%
all_artist_info = get_artist_info(all_artist_urls)

# %%
artist_df = pd.DataFrame.from_dict(all_artist_info, orient='index')
artist_df = artist_df.reset_index()

# %%
print(final_df.columns)
print("")
print(artist_df.columns)

# %%
artist_df = artist_df.rename(columns={'index': 'id'})

# %%
final_df = final_df.drop('index', axis=1).reset_index()

# %%
final_df = final_df.rename(columns={'index': 'id'})

# %% [markdown]
# # Creating SQLite Database with Python

# %% [markdown]
# ## Create/Connect to SQLite DB and Establish Connection

# %%
import sqlite3

# %%
conn = sqlite3.connect('soundcloud_data.db')

# %%
c = conn.cursor()

# %% [markdown]
# ## Create Tables

# %%
query_artists = '''
CREATE TABLE IF NOT EXISTS soundcloud_artists(
    id integer,
    artist_name text,
    artist_url text PRIMARY KEY,
    artist_toptrack text,
    artist_toptrack_views REAL,
    artist_followers REAL,
    artist_numtracks REAL)
'''

# %%
c.execute(query_artists)

# %%
query_tracks = '''
CREATE TABLE IF NOT EXISTS soundcloud_tracks (
    id integer PRIMARY KEY,
    track_genre text,
    track_title text,
    track_url text,
    track_artist text,
    track_views_week REAL,
    track_views_all REAL,
    track_artist_url text, 
    FOREIGN KEY (track_artist_url) REFERENCES soundcloud_artists (artist_url)
);
'''

# %%
c.execute(query_tracks)

# %% [markdown]
# ## Put Dataframes with Scraped Data in SQL DB

# %%
artist_df.to_sql('soundcloud_artists', conn, if_exists='replace', index=False)

# %%
final_df.to_sql('soundcloud_tracks', conn, if_exists='replace', index=False)

# %%
conn.close()

# %%
artist_df.shape

# %%
final_df.shape

# %% [markdown]
# # Separate Cache to write to Github

# %%
cache_full = open_cache()

# %%
cache_half1 = dict(list(cache_full.items())[len(cache_full)//2:])
cache_half2 = dict(list(cache_full.items())[:len(cache_full)//2])

# %%
save_cache_with_name(cache_half1, 'cache_half1.json')
save_cache_with_name(cache_half2, 'cache_half2.json')

# %% [markdown]
# # Combine 2 Cache Files into 1

# %%
cache_half1 = open_cache_with_name('cache_half1.json')
cache_half2 = open_cache_with_name('cache_half2.json')

# %%
cache_half1.update(cache_half2)

# %%
save_cache_with_name(cache_half1, 'sc_cache.json')
